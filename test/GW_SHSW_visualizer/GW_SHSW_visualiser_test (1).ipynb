# %%
import GW_SHSW_visualiser
# Out:
# /home/bhuvaneshwari.kashi/miniconda3/lib/python3.11/site-packages/waveformtools
# No module named 'config'

# %%
ell = 2
emm = 1
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics(True, "SWSH21")
# Out:
# Image is saved!

# %%
ell = 3
emm = 2
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics(True, "SWSH32")
# Out:
# Image is saved!

# %%
ell = 4
emm = 2
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics(True, "SWSH42")
# Out:
# Image is saved!

# %%
ell = 2
emm = 2
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics()

# %%
import time

# %%
start = time.time()
ell = 2
emm = 2
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics(True, "SWSH22")
end = time.time()
print(f"Execution time: {end - start} seconds")
# Out:
# Image is saved!
# Execution time: 59.153557777404785 seconds

# %%
import cProfile
profiler = cProfile.Profile()
profiler.enable()
ell = 2
emm = 2
visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
visualizer.plot_spherical_harmonics(True, "SWSH22")
end = time.time()
profiler.disable()
profiler.print_stats(sort='time')
# Out:
# Image is saved!
#          142599554 function calls (142591833 primitive calls) in 108.299 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   1770202    7.433    0.000    9.609    0.000 shape_base.py:612(column_stack)
#   3542915    6.803    0.000    6.803    0.000 {built-in method numpy.asarray}
#   1770125    5.664    0.000   30.059    0.000 path.py:191(_create_closed)
#   1770125    5.658    0.000   13.940    0.000 _methods.py:101(_mean)
#   1770286    5.452    0.000   20.979    0.000 path.py:99(__init__)
#   1770130    4.611    0.000   35.540    0.000 art3d.py:1032(<genexpr>)
#   2127522    4.202    0.000    4.202    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   1062075    3.989    0.000    4.394    0.000 cbook.py:1873(_array_perimeter)
#   1770125    3.701    0.000   19.389    0.000 function_base.py:398(average)
#   1770125    3.244    0.000    3.558    0.000 _methods.py:67(_count_reduce_items)
# ...

# %%
pip install line_profiler
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.4/748.4 kB 3.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from line_profiler import LineProfiler

def visualize_spherical_harmonics():
    ell = 2
    emm = 2
    visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
    visualizer.plot_spherical_harmonics(True, "SHSW22")

# Create a LineProfiler instance
profiler = LineProfiler()
profiler.add_function(visualize_spherical_harmonics)

# Run the profiler
profiler.run('visualize_spherical_harmonics()')
profiler.print_stats()
# Out:
# Image is saved!
# Timer unit: 1e-09 s
#
# Total time: 100.189 s
# File: /tmp/ipykernel_1498428/142331465.py
# Function: visualize_spherical_harmonics at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def visualize_spherical_harmonics():
#      4         1        922.0    922.0      0.0      ell = 2
#      5         1        171.0    171.0      0.0      emm = 2
#      6         1    1516763.0    2e+06      0.0      visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
#      7         1        1e+11    1e+11    100.0      visualizer.plot_spherical_harmonics(True, "SHSW22")

# %%
pip install memory_profiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from memory_profiler import profile

@profile
def visualize_spherical_harmonics():
    ell = 2
    emm = 2
    visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
    visualizer.plot_spherical_harmonics(True, "SHSW22")

# %%
# mprof run GW_SHSW_visualiser.py

# %%
# mprof plot

# %%
from memory_profiler import profile

@profile
def visualize_spherical_harmonics():
    ell = 2
    emm = 2
    visualizer = GW_SHSW_visualiser.GW_SpinWeightedSphericalHarmonicsVisualizer(ell, emm)
    visualizer.plot_spherical_harmonics(True, "SHSW22")

# Call the function
visualize_spherical_harmonics()
# Out:
# ERROR: Could not find file /tmp/ipykernel_1498428/3724597058.py
# Image is saved!
