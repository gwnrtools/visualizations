# %% [markdown]
# # SH Visualizer Demo

# %% [markdown]
# ### SHvis

# %%
from SHVisualizer import SHvis as shv

# %%
visualizer = shv(ell=2, emm=1)
visualizer.plot(save_fig=True, file_path="SH_21")
# Out:
# Image is saved!

# %%
visualizer = shv(ell=3, emm=3)
visualizer.plot(save_fig=True, file_path="SH_33")
# Out:
# Image is saved!

# %%
visualizer = shv(ell=3, emm=2)
visualizer.plot(save_fig=True, file_path="SH_32")
# Out:
# Image is saved!

# %%
visualizer = shv(ell=5, emm=2)
visualizer.plot(save_fig=True, file_path="SH_52")
# Out:
# Image is saved!

# %% [markdown]
# ### SHvisr

# %%
from SHVisualizer import SHvisr as shvr

# %%
visualizer = shvr(ell=2, emm=1)
visualizer.plot(save_fig=True, file_path="SH_21r")
# Out:
# Image is saved!

# %%
visualizer = shvr(ell=3, emm=2)
visualizer.plot(save_fig=True, file_path="SH_32r")
# Out:
# Image is saved!

# %%
visualizer = shvr(ell=3, emm=3)
visualizer.plot(save_fig=True, file_path="SH_33r")
# Out:
# Image is saved!

# %%
visualizer = shvr(ell=5, emm=2)
visualizer.plot(save_fig=True, file_path="SH_52r")
# Out:
# Image is saved!
