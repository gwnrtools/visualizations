# %% [markdown]
# # GW_onemode Demo

# %% [markdown]
# #

# %% [markdown]
# ## Demo1: gw1m_vis

# %%
from GW_onemode import gw1m_vis as gmv

# %%
import h5py

# %%
hdata = h5py.File('/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5')
ell = 2
emm = 1

# %%
v = gmv(hdata,ell,emm)
v.plot(True, '21_GWdatamode')
# Out:
# Image is saved!

# %%
hdata = h5py.File('/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5')
ell = 2
emm = 2
timestamp = 5000
v = GW_SWSHvis(hdata,ell,emm, timestamp)
v.plot(True, '22_5000_GWdatamode')
# Out:
# Image is saved!

# %%
hdata = h5py.File('/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5')
ell = 2
emm = 2
timestamp = 10000
v = GW_SWSHvis(hdata,ell,emm, timestamp)
v.plot(True, '22_10000_GWdatamode')
# Out:
# Image is saved!

# %% [markdown]
# #

# %% [markdown]
# ## Demo2: gw1m_anim

# %%
from GW_onemode import gw1m_anim as gma

# %%
# Example usage:
ell = 2
emm = 2
hdata_path = '/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5'
output_dir = 'GWmode22_100_24'
video_name = 'GWmode22_100_24.mp4'
fps = 24
step = 100

visualizer = gma(ell, emm, hdata_path, step, fps, output_dir, video_name)
visualizer.run()
# Out:
# Images are being created
# 100%|██████████| 161/161 [00:30<00:00,  5.24it/s]
# Images are saved in the output directory
# Images are being converted to video
# Your Video is ready

# %%
# Example usage:
ell = 2
emm = 2
hdata_path = '/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5'
output_dir = 'GWmode22_100_24_10'
video_name = 'GWmode22_100_24_10.mp4'
fps = 24
step = 10

visualizer = gma(ell, emm, hdata_path, step, fps, output_dir, video_name)
visualizer.run()
# Out:
# Images are being created
# 100%|██████████| 1605/1605 [04:36<00:00,  5.81it/s]
# Images are saved in the output directory
# Images are being converted to video
# Your Video is ready

# %%
# Example usage:
ell = 3
emm = 2
hdata_path = '/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5'
output_dir = 'GWmode42_100_24'
video_name = 'GWmode42_100_24.mp4'
fps = 24
step = 100

visualizer = gma(ell, emm, hdata_path, step, fps, output_dir, video_name)
visualizer.run()
# Out:
# Images are being created
# 100%|██████████| 161/161 [00:26<00:00,  5.99it/s]
# Images are saved in the output directory
# Images are being converted to video
# Your Video is ready

# %%
# Example usage:
ell = 6
emm = 3
hdata_path = '/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5'
output_dir = 'GWmode63_20_24'
video_name = 'GWmode63_20_24.mp4'
fps = 24
step = 20

visualizer = gma(ell, emm, hdata_path, step, fps, output_dir, video_name)
visualizer.run()
# Out:
# Images are being created
# 100%|██████████| 803/803 [02:28<00:00,  5.42it/s]
# Images are saved in the output directory
# Images are being converted to video
# Your Video is ready

# %%
# Example usage:
ell = 4
emm = 3
hdata_path = '/mnt/pfs/bhuvaneshwari.kashi/Visualizations/Clm/rhOverM_Extrapolated_N6_CoM.h5'
output_dir = 'GWmode43_20_24'
video_name = 'GWmode43_20_24.mp4'
fps = 24
step = 20

visualizer = gma(ell, emm, hdata_path, step, fps, output_dir, video_name)
visualizer.run()
# Out:
# Images are being created
# 100%|██████████| 803/803 [02:26<00:00,  5.50it/s]
# Images are saved in the output directory
# Images are being converted to video
# Your Video is ready
