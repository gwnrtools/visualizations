# %% [markdown]
# # SWSH Visualizer Demo

# %% [markdown]
# ### SWSHvis_usph

# %%
from SWSHVisualizer import SWSHvis_usph as gsu

# %%
visualizer = gsu(ell=2, emm=1)
visualizer.plot(save_fig=True, file_path="SWSH_21_sph")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 621.38%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 157.26%/s]

# %%
visualizer = gsu(ell=3, emm=1)
visualizer.plot(save_fig=True, file_path="SWSH_31_sph")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 669.54%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 170.58%/s]

# %%
visualizer = gsu(ell=4, emm=2)
visualizer.plot(save_fig=True, file_path="SWSH_42_sph")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 594.32%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 158.06%/s]

# %% [markdown]
# ### SWSHvis

# %%
from SWSHVisualizer import SWSHvis as gs

# %%
visualizer = gs(ell=3, emm=2)
visualizer.plot(save_fig=True, file_path="SWSH_32")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 670.66%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 178.76%/s]

# %%
visualizer = gs(ell=5, emm=3)
visualizer.plot(save_fig=True, file_path="SWSH_53")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 671.47%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 128.03%/s]

# %%
visualizer = gs(ell=5, emm=5)
visualizer.plot(save_fig=True, file_path="SWSH_55")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 668.90%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 179.78%/s]

# %%
visualizer = gs(ell=6, emm=2)
visualizer.plot()
# Out:
# ...
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 327.94%/s]

# %% [markdown]
# ### SWSHvisr

# %%
from SWSHVisualizer import SWSHvisr as gsr

# %%
visualizer = gsr(ell=2, emm=2)
visualizer.plot(save_fig=True, file_path="SWSH_22r")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 363.95%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:01<00:00, 96.53%/s]

# %%
visualizer = gsr(ell=3, emm=3)
visualizer.plot(save_fig=True, file_path="SWSH_33r")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 361.09%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:01<00:00, 93.77%/s]

# %%
visualizer = gsr(ell=4, emm=2)
visualizer.plot(save_fig=True, file_path="SWSH_42r")
# Out:
# ...
# Generating Plot:  80%|████████  | 80/100 [00:00<00:00, 128.66%/s]
# Image is saved!
# Generating Plot: 100%|██████████| 100/100 [00:01<00:00, 72.52%/s]

# %%
visualizer = gsr(ell=5, emm=5)
visualizer.plot()
# Out:
# ...
# Generating Plot: 100%|██████████| 100/100 [00:00<00:00, 178.90%/s]
